# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pandas_profiling
from statsmodels.graphics.gofplots import qqplot
from scipy import stats

# %%
df = pd.read_excel('~/Downloads/distrib.xls')

# %%
un = df['Un']
un = un.dropna()
sns.distplot(un)

# %%
un1 = un - un.mean()
sns.distplot(un1)

# %%
qqplot(un, dist=stats.uniform, line='q')

# %%
stats.kstest(un1, 'norm')
# Out:
# KstestResult(statistic=0.07334457358544744, pvalue=0.9034724954965163)

# %% [markdown]
# отримали p=0.87, тому можемо сподіватися, що дані розподілені досить нормально
# розмір вибірки досить малий для більш точної оцінки

# %%
print(un.mean())
print(un.std())
# Out:
# 3.5190598264514095
# 0.9173538014079718
