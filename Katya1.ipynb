# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pandas_profiling
from statsmodels.graphics.gofplots import qqplot
from scipy import stats

# %%
df = pd.read_excel('~/Downloads/distrib.xls')

# %%
un = df['Un']
un = un.dropna()
sns.distplot(un)

# %%
un1 = un - 3.5
sns.distplot(un1)

# %%
qqplot(un, dist=stats.uniform, line='q')

# %%
stats.kstest(un1, 'norm')
# Out:
# KstestResult(statistic=0.07655098557233886, pvalue=0.873463173964478)

# %%
stats.normaltest(un1)
# Out:
# NormaltestResult(statistic=7.232922308499548, pvalue=0.026877624157003923)
