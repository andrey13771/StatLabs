# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import statsmodels.api as sm
from statsmodels.graphics.gofplots import qqplot

# %%
df = pd.read_excel('C:/Users/JohnTitor/Downloads/2017_CompStat/crime.xls')

# %%
df = df[['R', 'NW', 'U1']]

# %%
sns.pairplot(df, kind='reg')

# %%
X = df[['NW', 'U1']]
Y = df['R']
X = sm.add_constant(X)
model = sm.OLS(Y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      R   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.042
# Method:                 Least Squares   F-statistic:                   0.07004
# Date:                Sun, 01 Dec 2019   Prob (F-statistic):              0.932
# Time:                        23:12:33   Log-Likelihood:                -237.91
# No. Observations:                  47   AIC:                             481.8
# Df Residuals:                      44   BIC:                             487.4
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         99.0721     33.128      2.991      0.005      32.307     165.837
# NW             0.0095      0.057      0.166      0.869      -0.106       0.125
# U1            -0.0998      0.327     -0.305      0.762      -0.759       0.559
# ==============================================================================
# Omnibus:                       11.652   Durbin-Watson:                   2.491
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               11.534
# Skew:                           1.109   Prob(JB):                      0.00313
# Kurtosis:                       3.985   Cond. No.                         926.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
qqplot(results.resid, line='s')

# %%
sns.distplot(results.resid)

# %%
results.outlier_test()
# Out:
#     student_resid   unadj_p   bonf(p)
# 0       -0.250953  0.803104  1.000000
# 1        2.601761  0.012846  0.578076
# 2       -0.958817  0.343271  1.000000
# 4        1.208680  0.233710  1.000000
# 5       -0.584717  0.561942  1.000000
# 6        0.318705  0.751568  1.000000
# 7        2.160566  0.036624  1.000000
# 8       -0.196191  0.845430  1.000000
# 9       -0.398850  0.692074  1.000000
# 10       2.644337  0.011547  0.519601
# 11      -0.075113  0.940490  1.000000
# 12      -1.176272  0.246271  1.000000
# 13      -0.691001  0.493459  1.000000
# 14      -0.186144  0.853250  1.000000
# 15       0.303211  0.763262  1.000000
# 16      -0.843331  0.403936  1.000000
# 17       0.149020  0.882268  1.000000
# 18      -0.399992  0.691239  1.000000
# 19       1.445168  0.156011  1.000000
# 20      -0.269574  0.788841  1.000000
# 21      -1.713516  0.094170  1.000000
# 22       1.062790  0.294097  1.000000
# 23       0.717930  0.476871  1.000000
# 24      -1.201342  0.236513  1.000000
# 26      -1.725801  0.091914  1.000000
# 27       1.191512  0.240305  1.000000
# 28       0.565229  0.574998  1.000000
# 29      -0.752768  0.455890  1.000000
# 30      -1.319159  0.194436  1.000000
# 31      -0.251071  0.803013  1.000000
# 32       0.563644  0.576067  1.000000
# 33       0.290599  0.772823  1.000000
# 34      -0.460643  0.647489  1.000000
# 35       1.316761  0.195232  1.000000
# 36      -0.356016  0.723654  1.000000
# 37      -0.855381  0.397312  1.000000
# 38      -0.186747  0.852780  1.000000
# 39       0.862288  0.393545  1.000000
# 40       0.049807  0.960518  1.000000
# 41      -0.869848  0.389448  1.000000
# 42      -0.303532  0.763019  1.000000
# 43       0.675883  0.502910  1.000000
# 44      -1.050864  0.299476  1.000000
# 45      -1.182381  0.243867  1.000000
# 46       0.126040  0.900316  1.000000

# %%
test = results.outlier_test()
outliers = test[test['unadj_p'] < 0.05]
outliers
# Out:
#     student_resid   unadj_p   bonf(p)
# 3        2.987805  0.004628  0.217539
# 25       3.070503  0.003696  0.173712

# %%
df = df.drop([3, 25])

# %%
X = df[['NW', 'U1']]
Y = df['R']
X = sm.add_constant(X)
model = sm.OLS(Y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      R   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                 -0.029
# Method:                 Least Squares   F-statistic:                    0.3776
# Date:                Sun, 01 Dec 2019   Prob (F-statistic):              0.688
# Time:                        23:13:16   Log-Likelihood:                -218.69
# No. Observations:                  45   AIC:                             443.4
# Df Residuals:                      42   BIC:                             448.8
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        102.2276     27.115      3.770      0.001      47.507     156.948
# NW             0.0176      0.047      0.375      0.709      -0.077       0.112
# U1            -0.1923      0.268     -0.717      0.477      -0.733       0.349
# ==============================================================================
# Omnibus:                        4.371   Durbin-Watson:                   2.295
# Prob(Omnibus):                  0.112   Jarque-Bera (JB):                3.724
# Skew:                           0.704   Prob(JB):                        0.155
# Kurtosis:                       3.050   Cond. No.                         915.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
test = results.outlier_test()
outliers = test[test['unadj_p'] < 0.05]
outliers
# Out:
#     student_resid   unadj_p   bonf(p)
# 1        2.601761  0.012846  0.578076
# 7        2.160566  0.036624  1.000000
# 10       2.644337  0.011547  0.519601

# %%
df = df.drop([1, 7, 10])

# %%
X = df[['NW', 'U1']]
Y = df['R']
X = sm.add_constant(X)
model = sm.OLS(Y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      R   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.049
# Method:                 Least Squares   F-statistic:                   0.04164
# Date:                Sun, 01 Dec 2019   Prob (F-statistic):              0.959
# Time:                        23:13:53   Log-Likelihood:                -194.37
# No. Observations:                  42   AIC:                             394.7
# Df Residuals:                      39   BIC:                             400.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         80.8876     22.075      3.664      0.001      36.237     125.538
# NW             0.0099      0.037      0.264      0.793      -0.066       0.086
# U1            -0.0168      0.217     -0.077      0.939      -0.457       0.423
# ==============================================================================
# Omnibus:                        1.705   Durbin-Watson:                   2.267
# Prob(Omnibus):                  0.426   Jarque-Bera (JB):                1.249
# Skew:                           0.180   Prob(JB):                        0.535
# Kurtosis:                       2.235   Cond. No.                         908.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
test = results.outlier_test()
outliers = test[test['unadj_p'] < 0.05]
outliers
# Out:
# Empty DataFrame
# Columns: [student_resid, unadj_p, bonf(p)]
# Index: []
